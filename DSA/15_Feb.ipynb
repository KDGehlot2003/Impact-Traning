# %%
# WAP to create two single linked list with four nodes and 
# compare the element of both linked list if the element are same then return true or else return false
# WAP to match the two sorted linked list



class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class linkedlist:
    def __init__(self):
        self.head = None
        
    def display(self):
        temp = self.head
        if self.head is None:
            print("Empty hai 🥲")
        else:
            while(temp):
                print(temp.data,end="--->")
                temp = temp.next
            
def compare(s1,s2):
    c1 = s1.head
    c2 = s2.head
    while (c1 and c2):
        if c1.data != c2.data:
            return False
        c1 = c1.next
        c2 = c2.next
    
    if (c1 is None and c2 is None):
        return True
    return False
        

def SORT(l1,l2):
    temp1 = l1.head
    temp2 = l2.head
    arr = []
    while temp1 and temp2:
        if temp1.data < temp2.data:
            arr.append(temp1.data)
            temp1 = temp1.next
        else:
            arr.append(temp2.data)
            temp2 = temp2.next
    while temp1:
        arr.append(temp1.data)
        temp1 = temp1.next
    while temp2:
        arr.append(temp2.data)
        temp2 = temp2.next
    
    
    for i in arr:
        print(i,end="--->")

n1 = Node(10)
n2 = Node(30)
n1.next = n2
n3 = Node(50)
n2.next = n3
n4 = Node(70)
n3.next = n4

l1 = linkedlist()
l1.head = n1
l1.display()
print()

d1 = Node(20)
d2 = Node(40)
d1.next = d2
d3 = Node(60)
d2.next = d3
d4 = Node(80)
d3.next = d4
l2 = linkedlist()
l2.head = d1
l2.display()
print()

print(compare(l1,l2))

print()

SORT(l1,l2)
# Out:
# 10--->30--->50--->70--->
# 20--->40--->60--->80--->
# False
#
# 10--->20--->30--->40--->50--->60--->70--->80--->

# %%
# WAP to match the two sorted linked list


#creating a node
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class ssl:
    def __init__(self) :
        self.head=None
    # displaying a data of ll
    def display(self):
        if(self.head is None):
            print("empty linked list")
        else:
            temp=self.head
            while(temp.next):
                print(temp.data,end="--->")
                temp=temp.next
            print(temp.data)
            
    def merge(self, n1, m1):
        dummy = Node(0)
        tail = dummy
        while n1 is not None and m1 is not None:
            if n1.data < m1.data:
                tail.next = n1
                n1 = n1.next
            else:
                tail.next = m1
                m1 = m1.next
            tail = tail.next

        if n1 is not None:
            tail.next = n1
        else:
            tail.next = m1

        return dummy.next
   
            
def equal(n1,m1):
        
    while(n1 is not None and m1 is not None):
        if n1.data!=m1.data:
            return False
        n1=n1.next
        m1=m1.next
    if n1 is None and m1 is None:
        return True
    return False



#inserting a node      
n1=Node(10)
n2=Node(29)
n1.next=n2
n3=Node(32)
n2.next=n3
n4=Node(40)
n3.next=n4
s1=ssl()
s1.head=n1
s1.display()
        
        
m1=Node(10)
m2=Node(24)
m1.next=m2
m3=Node(35)
m2.next=m3
# m4=Node(50)
# m3.next=m4
s2=ssl()
s2.head=m1
s2.display()

if(equal(n1,m1)):
    print("equal")
else:
    print("not equal")
s3=ssl()    
s3.head=s3.merge(n1,m1)
s3.display()
# Out:
# 10--->29--->32--->40
# 10--->24--->35
# not equal
# 10--->10--->24--->29--->32--->35--->40
