# %%
#WAP to reverse the linked list elements without using the list 


class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def __init__(self):
        self.head=None
        
    def reverse(self):
        prev=None
        current=self.head
        while(current is not None):
            next=current.next
            current.next=prev
            prev=current
            current=next
        self.head=prev
    
    def display(self):
        temp=self.head
        if(self.head is None):
            print("Empty")
        else:
            while(temp):
                print(temp.data, end="--->")
                temp=temp.next
                
n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.display()
print()
s1.reverse()
s1.display()
# Out:
# 10--->20--->30--->40--->
# 40--->30--->20--->10--->

# %% [markdown]
# # Stack and Queue

# %% [markdown]
# #implementation of stack using list

# %%
s=[]
size=int(input('enter the size: '))
top=-1

while(True):
    print('\n1.push,\n2.pop,\n3.display,\n4.exit')
    opt=int(input('enter your option '))
    if(opt==1):
        if(top<size-1):
            top=top+1
            ele=int(input('enter ele: '))
            s.append(ele)
        else:
            print("stack is full")
    elif(opt==2):
        if(top==-1):
            print("stack is empty")
        else:
            print('the deleted element is ',s.pop())
            top=top-1
    elif(opt==3):
        print(s)
    elif(opt==4):
        print('BYE')
        break
# Out:
# enter the size: 4
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 2
# stack is empty
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 10
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 20
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 30
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 3
# [10, 20, 30]
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 4
# BYE

# %% [markdown]
# #Implementation of stack using linked list

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None

class stack:
    def __init__(self):
        self.head=None
        
    def isempty(self):
        if(self.head==None):
            return True
        else:
            return False
        
    def push(self,data):
        if(self.head == None):
            self.head=node(data)
        else:
            temp=self.head
            ne=node(data)
            self.head=ne
            ne.next=temp
            
    def pop(self):
        if(self.isempty()==True):
            print('stack is empty')
        else:
            temp=self.head
            self.head=temp.next
            temp.next=None
            print('\nthe deleted element is ',temp.data)
            
    def display(self):
        temp=self.head
        if(self.head is None):
            print("stack is Empty")
        else:
            while(temp):
                print(temp.data, end=" ")
                temp=temp.next
        
s1=stack()
s1.push(10)
s1.push(20)
s1.push(30)
s1.push(40)
s1.display()
s1.pop()
s1.display()
s1.pop()
s1.display()
# Out:
# 40 30 20 10
# the deleted element is  40
# 30 20 10
# the deleted element is  30
# 20 10

# %% [markdown]
# #implementation of stack using dequeue

# %%
from collections import deque

s=deque()
s.append("krishna")
s.append(3+4j)
s.append(3.5)
s.append(6)
print(s)

s.pop()
print(s)

s.pop()
print(s)

s.pop()
s.pop()
print(s)
# Out:
# deque(['krishna', (3+4j), 3.5, 6])
# deque(['krishna', (3+4j), 3.5])
# deque(['krishna', (3+4j)])
# deque([])

# %% [markdown]
# #implementation of queue by using dequeue

# %%
from collections import deque

s=deque()
s.append("krishna")
s.append(3+4j)
s.append(3.5)
s.append(6)
print(s)

s.popleft()
print(s)

s.popleft()
s.popleft()
print(s)
# Out:
# deque(['krishna', (3+4j), 3.5, 6])
# deque([(3+4j), 3.5, 6])
# deque([6])

# %% [markdown]
# #implementation of queue by using list

# %%
q=[]
size=int(input('enter the size: '))
top=-1

while(True):
    print('\n1.push,\n2.pop,\n3.display,\n4.exit')
    opt=int(input('enter your option '))
    if(opt==1):
        if(top<size-1):
            top=top+1
            ele=int(input('enter ele: '))
            q.append(ele)
        else:
            print("Queue is full")
    elif(opt==2):
        if(top==-1):
            print("Queue is empty")
        else:
            print('the deleted element is ',q.pop(0))
            top=top-1
    elif(opt==3):
        print(q)
    elif(opt==4):
        print('BYE')
        break
# Out:
# enter the size: 4
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 32
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 21
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 1
# enter ele: 43
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 2
# the deleted element is  32
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 3
# [21, 43]
#
# 1.push,
# 2.pop,
# 3.display,
# 4.exit
# enter your option 4
# BYE

# %% [markdown]
# #implementation of queue by using linked list

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None

class queue:
    def __init__(self):
        self.head=None
        
    def isempty(self):
        if(self.head==None):
            return True
        else:
            return False
        
    def push(self,data):
        if(self.head == None):
            self.head=node(data)
        else:
            temp=self.head
            ne=node(data)
            self.head=ne
            ne.next=temp
            
    def pop(self):
        if(self.isempty()==True):
            print('queue is empty')
        else:
            temp=self.head
            while(temp.next):
                d=temp
                temp=temp.next
            d.next=None
            print('\nthe deleted element is ',temp.data)
            
    def display(self):
        temp=self.head
        if(self.head is None):
            print("queue is Empty")
        else:
            while(temp):
                print(temp.data, end=" ")
                temp=temp.next
        
s1=queue()
s1.push(10)
s1.push(20)
s1.push(30)
s1.push(40)
s1.display()
s1.pop()
s1.display()
s1.pop()
s1.display()
# Out:
# 40 30 20 10
# the deleted element is  10
# 40 30 20
# the deleted element is  20
# 40 30

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None

class stack:
    def __init__(self,size):
        self.head=None
        self.size=size
        
    def isempty(self):
        if(self.head==None):
            return True
        else:
            return False
    def isfull(self):
        if(self.size==None):
            return True
        else:
            return False
        
    def push(self,data):
        if(self.size==False):
            print('full')
        elif(self.head == None):
            self.head=node(data)
        else:
            temp=self.head
            ne=node(data)
            self.head=ne
            ne.next=temp
            
    def pop(self):
        if(self.isempty()==True):
            print('stack is empty')
        else:
            temp=self.head
            self.head=temp.next
            temp.next=None
            print('\nthe deleted element is ',temp.data)
            
    def display(self):
        temp=self.head
        if(self.head is None):
            print("stack is Empty")
        else:
            while(temp):
                print(temp.data, end=" ")
                temp=temp.next
        
s1=stack(input('enter stack size: '))
s1.push(10)
s1.push(20)
s1.push(30)
s1.push(40)
s1.display()
s1.pop()
s1.display()
s1.pop()
s1.display()
# Out:
# enter stack size: 5
# 40 30 20 10
# the deleted element is  40
# 30 20 10
# the deleted element is  30
# 20 10
